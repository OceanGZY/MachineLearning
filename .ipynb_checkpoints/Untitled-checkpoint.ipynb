# %%
a="2.2亿人下载 ・ 64.24MB"

# %%
b = a.split('・')

# %%
print(b)
# Out:
# ['2.2亿人下载 ', ' 64.24MB']

# %%
print(b[0])
# Out:
# 2.2亿人下载

# %%
print(range(42))
# Out:
# range(0, 42)

# %%
for i in range(42):
    print(i)
